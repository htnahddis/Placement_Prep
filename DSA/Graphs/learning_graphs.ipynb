# %% [markdown]
# Graphs in python are created suing adjency lists. Where each stores the negihbours of each graph

# %%
graph = {
    "A" : ["B", "C"],
    "B" : [],
    "C" : []
}

# %%
graph = {}

def add_edge(u,v):

    if u not in graph:
        graph[u] = []
    
    graph[u].append[v]

# %%
"""
For checking the unique again and agsin we can simply use default dictionaries. 
"""

from collections import defaultdict

g = defaultdict(list)

g[1].append(2)
g[3].append(2)

print(g)
# Out:
# defaultdict(<class 'list'>, {1: [2], 3: [2]})
