# %% [markdown]
# LLM Gateways:
# It is a smart middleware layer that sits betwen the app and the LLM providers
#
# The features it provided are as follows:
# 1. Rate Limiting
# 2. Load Balancing
# 3. Unified api
# 4. Caching
# 5. Cost tracking
# 6. Fall backs
