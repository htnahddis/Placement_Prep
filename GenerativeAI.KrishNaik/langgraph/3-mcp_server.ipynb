# %%
# %pip install langchain-mcp-adapters
# %pip install langchain-groq
# %pip install mcp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# GEMINI_API_KEY =AQ.Ab8RN6Iia9K2P5KZ9YNYxFWEOB8rn8a3uP5bMT7V_Q0ZiU3BJw
# # OPENAI_API_KEY =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
# # GROQ_API_KEY=gsk_nA59pC0QqdpvprM8QXjgWGdyb3FYX6nRuFyFezLg8Uzg7d9x30
# # OPENROUTER_API_KEY =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
# # TAVILY_API_KEY=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
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 16
#      13     return a*b
#      15 if __name__ == "__main__":
# ---> 16     mcp.run(transport ="stdio")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mcp\server\fastmcp\server.py:296, in FastMCP.run(self, transport, mount_path)
#     294 match transport:
#     295     case "stdio":
# --> 296         anyio.run(self.run_stdio_async)
#     297     case "sse":  # pragma: no cover
#     298         anyio.run(lambda: self.run_sse_async(mount_path))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\anyio\_core\_eventloop.py:62, in run(func, backend, backend_options, *args)
#      44 """
#      45 Run the given coroutine function in an asynchronous event loop.
#      46
#    (...)     59
#      60 """
#      61 if asynclib_name := current_async_library():
# ...
